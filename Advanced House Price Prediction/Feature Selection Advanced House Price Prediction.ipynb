# %% [markdown]
# # Feature Selection Advanced House Price Prediction

# %%
# The main aim of this project is to predict the house price based on various features which we will discuss as we go ahead

# Dataset to downloaded from the below link
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#for feature selection
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

#to visualise all the column in the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv(r'C:\Users\Manoj Nahak\Krish Naik Youtube\Advanced House Price Prediction\train.csv')

# %%
dataset.head(4)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
#capture the dependent Feature
y_train = dataset['SalePrice']

# %%
#capture all Independent Feature
x_train = dataset.drop(['Id','SalePrice'], axis=1)

# %%
# Apply Feature Selection
# first, I specify the Lasso Regression model, and I
# select a suitable alpha (equivalent of penalty).
# The bigger the alpha the less features that will be selected.

# Then I use the selectFromModel object from sklearn, which
# will select the features which coefficients are non-zero
feature_sel_model=SelectFromModel(Lasso(alpha=0.005, random_state=0))# remember to set the seed i.e. the random state
feature_sel_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f8239a0cf4b3> in <module>
#       7 # will select the features which coefficients are non-zero
#       8 feature_sel_model=SelectFromModel(Lasso(alpha=0.005, random_state=0))# remember to set the seed i.e. the random state
# ----> 9 feature_sel_model.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\from_model.py in fit(self, X, y, **fit_params)
#     195                 "Since 'prefit=True', call transform directly")
#     196         self.estimator_ = clone(self.estimator)
# --> 197         self.estimator_.fit(X, y, **fit_params)
#     198         return self
#     199
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py in fit(self, X, y, check_input)
#     711             X, y = check_X_y(X, y, accept_sparse='csc',
# ...
